# %% [markdown]
# 1. 引入必要的Python库

# %%
import numpy as np
from PIL import Image
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertConfig, BertModel
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from model.BERT_RESNET import bertResModel
from model.BERT_ALEX import bertAlexModel
from model.BERT_VGG import bertVGGModel
from model.text import textModel
from model.image import imageModel

# %% [markdown]
# 2. 调用GPU

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device:', device)
# Out:
# device: cuda:0

# %% [markdown]
# 3. 观测数据集形态

# %%
for idx in range(1, 1001):
    with open('./data/' + str(idx) + '.txt', encoding='gb18030') as fp:
        text = fp.read()
        print(text)
# Out:
# How I feel today #legday #jelly #aching #gym
#
# grattis min griskulting!!!???? va bara tvungen oki s? sch ? @ingenkommeratttrodig #pig #happybday #wow #lovely #cut…
#
# RT @polynminion: The moment I found my favourite tV character. #PROFOUNDLOVE
#
# #escort We have a young and energetic team and we pride ourselves on offering the highes #hoer
#
# RT @chrisashaffer: Went to SSC today to be a "movie star" to rep for the Deaf and got to meet an energetic great guy: Mark White!
#
# RT @babeshawnmendes: "that was really energetic"
#
# RT @deepikapadukone: To my most hard working,fun loving and energetic team...Thank you and I love you!
#
# Energetic training today with our San Antonio New Dollars/New Partners trainees
#
# Look at their Photo and feel the #Anger. #SpeakUp for #peace. Speak up for #equality. Speak up for #Tolerance.
#
# @ArrivaTW absolute disgrace two carriages from Bangor half way there standing room only #disgraced
#
# RT @Dthompsonsmile: So proud of these kids! Not only talented, ENERGETIC and hardworking, but respectful and kind-hearted! ??
#
# RT @cosy_cosy: What does everybody think of these candles from Liberty London. We love! RT if you feel the same #Valentinesday
#
# I can't even tell you guys how much I love these covers ? @Melissa_Landers #invaded #alienated #prettycovers
#
# RT @ChesterPerforms: An energetic @sbutlerbooks tells us all about his sister - "the most evil bumface in the world'!! #WayWord #Chester ht…
#
# Awesome record. Keepin the night energetic ??
#
# RT @VenusCaelestis: You are a #manifestation of energetic potential. #truth #quote #DivineSociety
#
# Love to party? We're hiring fun, outgoing, energetic & happy people. Call or visit us to learn more.
#
# RT @JoeyXcv: when a girl texts you first and then ignores your reply
#
# #depressed #depression #bullied #anxiety #overdosed #addict #drugs #pills #cuts #cutting #…
#
# Winners will be chosen in 1 week.
#
# Thank you to Eastwood 8th grader Sam L. for helping hang 7th grade #SafeDates Valentines Day cards. #Caring
#
# Enraged by this? Then spread awareness! Loyalty...betrayed... #StopYulin2015
#
# I am enthusiastic about Gleeeeeeeeeeeeeeeeeeee????
#
# Looking forward to #Disgraced by Ayad Akhtar! Monday and tuesday are already sold out!
#
# RT @curiosityhouse: Author @CarolynjMorris reads to an enthusiastic audience #BigHeartDays @CreemoreOntario
#
# Waxwing trills, Chickadees calling "here sweetie", enthusiastic athletes, blue sky & snow at #ualbertafarm #UAlberta
#
# RT @PoshbikesDotCom: Cycling hero Greg LeMond stopped by the @PoshbikesDotCom stand today. Super enthusiastic about our brands!
#
# RT @Beltrew: Enthusiastic hello from the kids of Zarqa #Jordan-a poor area where many of the country's extremists come from
#
# RT @attorneybharti: Met this enthusiastic group of badminton players during today's morning park visit in gautam nagar.
#
# RT @CNNPolitics: It was eight years ago last week that Obama launched his first bid for president
#
# @ipaca_official @NTChoir great valentines treat singing all day with fellow enthusiastic teachers :-)
#
# RT @EnthusiasticKAT: Karl-Anthony is enthusiastic about reminding South Carolina about the last time they sent a team to play at Kentucky h…
#
# We listen to our customers and we know what you really want #caring #propertyexperts
#
# RT @TweetLikeAGirI: rt to save a life
#
# RT @PerfSneakers: Adidas mi ZX flux
#
# RT @Timmindie: This is so important
#
# RT @capostatus2015: Happy Valentine's Day
#
# RT @Footy_Jokes: Mario finally has a smile on his face!
#
# RT @MattBoutDatLife: Kanye brought out Fetty Wap. Don't question his judgement ever again
#
# RT @EuropiannChick: My sisters the real MVP ?? #ValentinesDay
#
# 3 New Tips to Handling Your Anger #anger #issues #love #relationship
#
# RT @MADBLACKTHOT: Crazy? She didn't lie RT @ImaniTsunami: this is legit crazy :/
#
# #Tagline #Disney #dismal #RooneyMara #EverRacistLand
#
# RT @FreddyAmazin: When someone insults you & they think you actually care
#
# RT @TheBucktList: Bora Bora ??
#
# RT @Lexxinnn: Meek done set it off with this one ???
#
# RT @KeepUpdated1D: WHAT IS ZAYN DOING TO ME?
#
# RT @Nabulax: i could slide on these eyelashes
#
# Mike RT @1GottaGo: Filmography: Mike, Adam, Jim, Will #1GottaGo
#
# #colorsplash_bw #zealous Penny #stock conspiracy - great converting product: Multi-mill
#
# Martha said for Valentine's Day she wanted a heart shaped pancake for lunch. Being the doting husband I am…
#
# This year, for the first time I'm doting on kouhais... normally I'd be like
#
# #soutmanf Stand W73 until Thursday #laser #cut #weld
#
# RT @TaoOfDolly: DOLLY HERO Meet 25 yr-old Meg, Britain's oldest dog! Rescued from puppy farm by doting dogdad http:/…
#
# だいぶ眠い。仮眠とるか。#廃墟 #abandoned #ruins #haikyo #urbex #写真好きな人と繋がりたい
#
# Effects 137,000 women + Illegal 30 years, no-one in Britain yet convicted of FGM #disgraced
#
# As proud of the @QuinsRugbyUnion lads as a doting (young!) mum. @ChrisRobshaw @nick_easter @JoeMarler @mikebrown_15
#
# RT @MyDreamBiggest: @AndreaNavedo Jane's baby not even born and Xo is already drooling he ... It's going to be a doting grandmother. ?? htt…
#
# RT @minjastars: im just doting on my daughter gomen tl
#
# RT @RobertWRossEsq: William Bruce Ellis Ranken's ebullient portrait of the young Ernest Thesiger. Born this day in 1879.
#
# Watching all the flies go by! Which one shall I attack first? ?? #Fefeswanson #kitten #cut…
#
# This beer goes well with Ghost Bath's 'Moonlover'. Some ebullient stuff going on, just wish the vox were cranked up.
#
# Campaigning in Polegate this morning with the ebullient @MariaCaulfield and the frugal Francis Maude.
#
# RT @LostboxUK: RT @brianwhelanhack: Anyone missing a cat in #Stokey? This bloke running around #Benthal, seems a little distressed. http:/…
#
# RT @olumayungbe: The next President of our beloved Nigeria. My friend, Ebullient GMB. Buhari .
#
# #nowplaying ELISA - ebullient future / rainbow pulsation ～THE BEST OF ELISA～
#
# Even a packed Edinburgh to Glasgow evening train is fun in the company of ebullient art writer, Anne Ellis.
#
# The beautiful and radiant sight of Hull City's stadium awaiting the arrival of #avfc ;) #Creepy #Bleak
#
# #VoilàSnackbar #WorstPresidentEver #POTUS #Disgraced #ISIS
#
# #NowPlaying ebullient future (English) / ef - a tale of melodies. / ELISA #これ聴いてるんだからねっ！
#
# Wenn Jim Carry will, ich w?r bereit für "Dumb and Dumber III". #cut #viel #gesicht
#
# MacBook Air falls over 300 metres from a plane - and survives the landing @Ebullient_Vinay
#
# RT @ChannelNewsAsia: Crowds attack Ebola facility, health workers in Guinea
#
# RT @coronairene75: Beyond ecstatic that my stuff come in today, @SnowThaProduct hook it up! Thanks baby!?#wakeyagameup #productpusha http:/…
#
# #django doing a fox impression. #cat #black #longhair IG > imaakim
#
# I couldn't be more ecstatic today. I have been waiting 8 years for 101 Dalmatians to release from the Disney Vault!
#
# RT @TabithaThomas95: ECSTATIC to have been scouted at @MOVEITSHOW with my best gal @Maddie_Painx ?? thank you @WilkesAcademy !!
#
# RT @4Ever4Animals: Shelter Dogs On Their Way Home For The First Time -
#
# RT @hayleyforson: 2 hours down, 6 to go! Learning to ski is knackering but so much fun ? @Snow_Factor #ski #olympia2024 #aching #smiles htt…
#
# Grab your brain mittens twitter I'm super ecstatic to be at work.. ??
#
# Pakistan players ecstatic after PCB credited 20 rupees bonus in their accounts #IndvsPak
#
# PAS Teens are on #Broadway! Excited to see #Disgraced - @ParkAvenueSyn
#
# #erza #anime #fairytailgirl #fairytail #kawaii #cut…
#
# RT @JacobJaber: Ecstatic to be working out of our new home office in the Dogpatch! Cc: @PhilzCoffee
#
# RT @FreeinDCBlog: Today! One Billion Rising Ecstatic Dance Party in Malcolm X/Meridian Hill Park 2pm-4pm, Free http:…
#
# Nuneaton fans at Gateshead today. The 26 went away ecstatic after a 2-1 win. Respect to all who travelled!
#
# Watching Titanic on Valentine's Day while eating a crap ton of chocolate... I'm just... So ecstatic. Can't you tell??
#
# RT @EdinaDanceTeam: For our first time at state we are ecstatic on taking 4th place in AAA finals! Congrats to all the amazing teams! http:…
#
# Ecstatic to be holding the first print copy of Wind In Your Sails. #biz #author
#
# #news #New post: #UN #alarmed at #rising #attacks against #schoolgirls #worldwide
#
# Hot Steamy Nights and Elated Feelings Make For A Great Valentine Evening! Sensual Thoughts @
#
# Oprah Winfrey is elated about a novel she recently finished reading #read
#
# RT @EducacionTigre: El #CUT ofrece carreras de cinco Universidades y el #CBC de la UBA. Informate al 4512-4399 o al mail cut@tigre.gov.ar h…
#
# @iNationalSRKian good 2 know dat! am elated in fact to know that! ctually no SRKians are-we are too good as a family!
#
# @planet_anita Dear Anita - My Finest Regard To You As Far As 100% Total Elated Valentine's Day MMXV In The Florida @
#
# Picture Frame #Distressed Red Black #Sentiment How Sweet It Is To Be #Loved By You #etsy
#
# RT @AtBestIsKorny: Elated to see "Burroughs: The Movie" @HowardBrookner DVD is forthcoming via @Criterion
#
# Logarusic elated with win @OfficialGMFC @macykiss
#
# @__Dave24 looks so elated ?
#
# This is my Valentine's from 1 of my nephews. I am elated; sometimes the little things are the biggest & best things!
#
# Just when you thought you'd seen everything! .... #ParkingSpace #Lanzarote #ItsNOTtaxed #zimmer #oldpeople #alarmed ?
#
# RT @IDA_SINGAPORE: It's @TimDraper w @ChannelNewsAsia Tim hosted @steveleonardSG @DraperHeroCity & we r elated to host Tim @comebash http:/…
#
# Nigga kilt that shit I bet
#
# RT @kaze_fu: #women #wristwatch #Women #Watch #Timex #Strap #Python #Black Met all my expectations. Nee…
#
# RT @annaswaim: At a forum to discuss @lrsd takeover and having ZERO confidence in State's interest in helping distressed schools.
#
# #Disgraced: Great performance, humor right on point & realism spot on. Now, how can I get a copy of the play/script?
#
# RT @RebelsSpartaCon: RT if you would stand with #Agron @DgFeuerriegel upon the sands of #Spartacon! Let voice be elevated to the Gods! http…
#
# HO BRASS MTS MANHATTAN ELEVATED EL CAR SET, 2 CARS, PAINTED
#
# RT @whoisluka: Guess who back
#
# “@preishaaaa: "@OverlyLiked: Bruh ??? im done.
#
# I can't even tell you guys how much I love these covers ? @Melissa_Landers #invaded #alienated #prettycovers
#
# RT @BlkHistStudies: One Love & Unity!
#
# S/O @DJOKGeneral x @TheOnlyGC [M!E]
#
# Vote #Conservative, the traditional party that elevated gay partnerships to marriage in law & sold its soul.
#
# RT @designboom: this guest house by korean architect moon hoon features an elevated terrace...
#
# #Broadway #Play "#Disgraced" #Pulitzer #Prize #Winner by #AmirKapoor. #NYC #TimesSquare #NewYork #Manhattan #Theater
#
# Some of the many static caravans that pop up in clusters along the British coast, most of which are empty in winter.
#
# Quantum of the seas under dramatic clouds. Notice the empty pool-- too cold and windy today. Tomorrow Florida.
#
# RT @ADropOfJensen: "I'm hunted, I rebelled, I did it, all of it, for you" #ProfoundLove
#
# Buscando um novo rumo que fa?a sentido nesse mundo louco .. ? #peace #love #cut #cabofrio #rj #022
#
# @Melissa_Landers look what came in the mail today. I'm so excited to get started. Yay. #alienated
#
# RT @polynminion: Dean probably thought Cas was really cute with his upside down FBI badge. #PROFOUNDLOVE
#
# #HappyValentinesDay to all you followers (whether your #heart is contempt or empty)
#
# THIS remIX MAKES ME DIZZY
#
# RT @ChrissyCostanza: "Mom what should I do with this empty bag." "It's a hat duh"
#
# Captivity? No Thanks! He'll empty ALL those tanks ! @SimonCowell #Cowell4Dolphins
#
# I still respect the man. #speechless “@WSJ: NBC suspends Brian Williams for 6 mo without pay:
#
# RT @hayleyforson: 2 hours down, 6 to go! Learning to ski is knackering but so much fun ? @Snow_Factor #ski #olympia2024 #aching #smiles htt…
#
# @Sheepthemoon @TheLegendofJill couldn't go home empty handed.
#
# #depression #anxiety #worry #grief #anger #fear #hopeless #doubt #shame #guilt
#
# RT @octuse: I have shipped for over 5 years and it wasn't until 2 years ago I fell hard for these two. #PROFOUNDLOVE
#
# RT @harryftansel: Oh my god???
#
# RT @jordansuckley: Look what we found at the Airport in Kuala Lumpur! #damaged #chairs
#
# #Dismal #monology by #Olavi #Paavolainen vs Dismal #SaltyLiquorice by @oypoppamies.
#
# RT @JustineSkye: Shot from last nights show #unicornnation
#
# RT @AnglinChanel: yu haven't lived til' you've chewed, sucked, & gnawed pon dis.. ????? #Caribbean #TeamJamaican
#
# RT @MalikaBanks: this 365 shit ? my boyfriend better than yours ?? @ItsBeenA_Drill love youuuuu ???
#
# RT @fatbellybella: They meet ...
#
# Sweet Obsession Euphoric Rechargeable Silicone Massager Waterproof Pink -
#
# "#art @artfinderlatest @artfinder Passing Storm @StellaDunkley" http:/…
#
# RT @firryasin: During My Warm Up Set Mysterious World Pre-Party Presents Jordan Suckley #TechnoBoy #DAMAGED
#
# RT @tamaka_669: The Onion is euphoric today: Local Church Full Of Brainwashed
#
# RT @EdMatts: "A climate of fear is your friend; a euphoric world is your enemy." Warren Buffett
#
# RT @femaIes: the matte black audi r8 is beautiful ?
#
# "@_MusicForLovee: Happy Valentines Day Bby ???? ???????
#
# RT @lKeepItReaI: i didn't know they put jokes on skittles wrappers now
#
# Does anyone find the cover of @nypost offensive and distasteful? #Appalled #bobbikristina
#
# RT @CraziestSex: my childhood has been forever changed ?
#
# RT @FreddyAmazin: i love tumblr ??
#
# RT @pauladavies18: PLEASE RT...Keep a look out for this evil bitch. If she comes to see your dog's, slap her one!!!.
#
# ?→ #5X10 #Distressed Sentiment Quote Photo Frame #Valentine Gift Shabby Chic Home Decor
#
# RT @NECA_TOYS: “@afthefly: @NECA_TOYS randy you went and made me want a GREMLIN! I'm evil like that
#
# RT @AUFAMILY: Good wins over evil as there are once again two lives oaks at Toomer's Corner. War Eagle! #ToomersForever
#
# RT @verge: The NSA just captured the evil side of Valentine's Day in this perfect tweet
#
# Tales Of Evil PhD Supervisors: 10th story - Vacation?
#
# @NCMUSICOFFICIAL you made my grans day!! #Delighted ??
#
# Harshad's second Missionn ? @har1603 what did you do??? #appalled
#
# RT @ItsWaltBitch: That’s right, Holly.
#
# RT @Awesomepiczs: Albert Einstein's theory on the existence of evil.
#
# U @IDFSpokesperson will wish you never served for #Israel. Because of strength like this despite evil Settler crimes
#
# 2 weeks until I can meet my idol @TanyaBurr! I'm so excited! ?? xx
#
# My excited Saturday work face. Is it 5 o'clock yet?
#
# Retweet:- if u excited to Gautam as chulbul pandey? http:/…
#
# #Woman #stabbed #rescuing #friend from #abusive #boyfriend
#
# Got some sweet #packers merchandise for my birthday including this hoodie. #delighted @packers_uk @OvertimeIreland
#
# Can't wait to see the #BATBD episode tonight with guest star @michaelirvin88! So excited @Brecbassinger @CoyStewart
#
# RT @zxkia: RETWEET IF YOU'RE EXCITED ????
#
# Really @ClevelandClinic ?? With 1/3 kids dealing with disease [obesity] you’re recommending this? #Appalled #shameful
#
# RT @HandsomeFellowG: When you get excited to watch the Grammys and you get told Rhianna is performing..
#
# RT @crashspain: Wonderful Turner Field Tour today. So excited for baseball season. Thanks @Braves @BravesReddit
#
# RT @FleurEast: Last night was the first night of The X Factor tour!!! Belfast was an amazing crowd! So excited for tonight!!! ??
#
# RT @TheView: Where are our @NayaRivera fans?! RT if you're excited to watch Naya guest co-host @TheView on Tuesday! ?
#
# New kicks from @tenniswarehouse #delighted
#
# Damn @jes_chastain looks amazing and creepy. Can't wait to watch #CrimsonPeak I'm absolutely exhilarated
#
# Exhilarated, exhausted and emotional. Must have been my first @WomenInUNISON national conference! #unwc15
#
# We asked @rebeccaminkoff for the one word that describes her state of mind leading up to her show... #EXHILARATED #…
#
# He exposed me to real & now I HATEEEE lames ??? My Monkey?? >>>
#
# RT @_cheeseburguer: “@Ashton5SOS: Here's some gossip...mikes underwear exposed #wow butt ?
#
# Throwin that shade #beanie #delinquent #braid #frozen #lmao
#
# "@TV_Exposed: Tom Cruise sitting on top of Burj Khalifa for Mission Impossible: Ghost Protocol @FeyikemiA_B
#
# EXPOSED: free fortune cookie SCAM at uwindsor marketplace #thatsnotafortune #appalled #fortuneless #cookiewasgoodtho
#
# ?? #5X10 #Distressed Photo Sentiment Quote Picture Frame 4X4 Photo Opening #Valentine Gift
#
# @Yngwildnpolshed buy2 get 1 at target!! Cant wait to go home and play! ? #bahamamama #marshmallow #wicked
#
# Just learned Girl Scout cookies are now $5 per box. #APPALLED #DISBELIEF #INFLATION #FormerGirlScout
#
# RT @gerardsoong1234: @RavenHUWolf @GodLovingTexan @ChuckNellis 2nd top Daesh twitter after Shami is now exposed! Thanks to @Lompemann ! htt…
#
# Cruel 'Treatment' of Dolphins 2 b exposed by @SimonCowell #Cowell4Dolphins
#
# Orlandooo? ? RT @TV_Exposed: Peter Jackson with the cast before the filming of Lord of the Rings
#
# Ukraine crisis: 'Dangerous' British student exposed as pro-Russian fanatic with Putin links…
#
# Dang @MCPLMO has no chill #Delinquent
#
# RT @UnknowFirst: ASARD KASSIM, #London #ISIS webmastr of EXPOSED #OpISIS #OpIceISIS @AnonOpsSE @OfficialAnonOps http…
#
# Hot #thong #ass posted by @PantyhoseMilf - #thongexposed
#
# This doesn't even look like Kerry.. #appalled
#
# My fave mascara and brow powder by @CBVisage All my own lashes no false eyelashes here!
#
# RT @PeaceFlowers12: ISC protest telling the False #DalaiLama to Stop Lying ouside the Town Hall in #Copenhagen
#
# RT @SharonHoole: .@HeraldZimbabwe who counted #zimbabweelephants? NOT ZANUPF they submit false figures 2 feed #China Bloody Ivory!
#
# A #boyhood like no other @MortalEndBook #thrilling #dark #mystery #horror #depraved #fairytale
#
# Can you feel it?!!? The new record is moving along nicely. #hopeclayburn #ardent #y'all loud!
#
# Ynn.io: Wink's promise of a simple, afforda... https://t.co/rHweoorts1 via @youthsnews #mashable
#
# @zealous_sisters_apparel #dress #celine #fashion #zealous #sisters #apparel #fashionistas …
#
# Funny how peopel make false allegations and think by lieing for the crimes they commited fucked up my life
#
# RT @AvoKegeyan: My worst and only fear.
#
# RT @SimpsonsQOTD: "Oh, don't you worry, most of you will never fall in love and marry out of fear of dying alone."
#
# RT @PTIofficial: #PakvInd Imran’s message to team: Abandon fear of losing via @dawn_com
#
# (with a slight bit of fear)
#
# There’s #power in looking #silly and not #caring that you do
#
# (Psalms 111:10) The fear of the LORD is the beginning of wisdom a good understanding have all they that do his com...
#
# From the ofc, now at The Other Office for some cold beer and fish and chips. #destress #distressed
#
# RT @fatbellybella: Fear stinks .. “@chancetherapper: But they fear us just the same. @fatbellybella ??????
#
# One #TheBoardrAm skater will earn an invite to ? Games Austin.
#
# If the body be feeble, the mind will not be strong. -- Thomas Jefferson
#
# West Ham must move on from feeble West Brom FA Cup debacle as soon as possible -
#
# FERVENT | S,M,L | 140k free PLASTIC CLIP, keychain rubber AND sticker 085725737197 / 28ae36f3
#
# Word for Today: ardent. adjective. having, expressive of, or characterized by intense feeling; passionate, fervent.
#
# He had no #failings which were not owing to a #noble cause; to an #ardent, #generous, perhaps an immoderate passion…
#
# RT @ApostleLauretta: The effectual fervent prayer of a righteous man availeth much. #PrayerIsMyMedicine?
#
# RT @mrgeology: .@orvinsezmore Ironically, Goebbels was a fervent socialist. cc: @ChrisLoesch
#
# RT @DesignItDevin: Finally finished the avatar for @PenguinOracle! RT's and favorites are always appreciated! :D
#
# Finished today training chest and triceps
#
# Finished foundry. Now I just need safety gear, and I'll be popping out aluminum biscuits f…
#
# RT @Paul_nevs: @gordonjbuchanan Thought you might like my image of a wolf I recently finished
#
# RT @VIXXMY: did they just finished swimming?? I'm glad they had time to have fun ?? #HAPPYRAVIDAY
#
# RT @888infinito888: not finished ? #art #arte #artwork #artcolor #artist #bolígrafo #boceto #colour #creative … http…
#
# RT @Lintufriikki: not finished yet but i gotta share these dorks anyways omgg
#
# Cake is finished! Proud of it tbh so hey ho. ?
#
# I literally just finished eating all the chocolate in my house, and my dad comes by with this. ? D'awe.
#
# RT @RayleighHiFi: Just finished off installing this simple yet superb Hi-Fi system.@HiFiRacksLtd @neatacoustics @ArcamUK @RegaResearch http…
#
# ?{ #girl #ana #depressed #pills #tired #sws #ptv #bands #music #cats #cuddles #raz…
#
# RT @Poofy_Fluffkins: man this one was tough. finished Con badge for @imaginehiswings
#
# Baddieeee RT @1NA_Trillion: Beautifully Flawed
#
# You don't have to be perfect to be whole! #JustBeWell
#
# Thank you @WedFlowersMag for featuring Sally' designs in your March/April issue #delighted ?
#
# RT @loveucats: #notme #ana #anorexia #mia #bulimia #deb #depressed #depression #sue #suicide #suicidal #c…
#
# RT @5SOfSImagines: You shout at fans because they won't let you see your boyfriend and he starts laughing at how flustered you get ~H http:…
#
# @cleethorp_es by emmal940 Fifty shades of grey on #cleethorpes #beach #bleak #winter #walks #springerspaniel #home
#
# [Moe bot][#9517] Maid outfits make her flustered [#toaruSeries]
#
# RT @gill_griffith: What a terrible terrible statement. A.A.Gill...hang your god forsaken head in shame. ....
#
# Frightened, but feeling ok about it
#
# Found a cold, tired, hungry, frightened black cat in our yard today. He's been there a few days, anyone missing him?
#
# RT @BigotExposed: Last time I shared this UKIP were fuming. Seeing as they think it's gone away I thought best to share again.
#
# #cycling #Mountain.. #Maxxis #Ardent Great set of tires for tacky conditions. If you ride …
#
# When you birdie a hole but lose it to a 'Nett Eagle' and you're absolutely fuming inside #GCW
#
# Gorgeous @TaraCaballero1 will be back tightly bound, gagged, frustrated and fuming in May
#
# So you pay for a full bag of anything these days and you get half or 3/4! #joke #con #fuming
#
# RT @TodoMotorVe: #SabadoNissan Se vende el #Nissan Skyline de #PaulWalker que utilizo en Fast and Furious
#
# FAST & FURIOUS 6 MOVIE COLLECTION DVD BOX SET VAN DIESEL #movies #dvd #bluray #horror #…
#
# RT @stoned_satan: https://t.co/y8SXRiJrP8 #cigarette #death #depressed
#
# RT @CazZxox: #dizzy #GamerGate #PS3 #perfect
#
# RT @njudah_star: POST MATCH: Dean Smith furious after @WFCOfficial penalty debacle #wfc
#
# When that whip bout to be too furious
#
# A first: When when your 2-liter falls through the bag= 20 ft rocket launch, & huge puddle of pop. #baffled #bagfail
#
# RT @BBCSporf: VIDEO: Footage of furious West Ham fans abusing owner David Sullivan after defeat!
#
# RT @AzaleansFR: #INFO @IGGYAZALEA et @wizkhalifa on fait un ft. ensemble pour "Fast and Furious 7"!
#
# RT @Irmak_Ye: #?zgecanAslan murder: men kept at bay at the funeral. Women of #Turkey are furious as hell.
#
# Too Fast and Too Furious? - New Photos and Details!
#
# RT @LemonThompson: Face still really swollen. #Depressed #Tonsils
#
# Books piling up ... so much pressure and gleeful anticipation.
#
# Too cute Tish! “@lawnfawn: Latisha created a sweet card full of dimension and layers!
#
# #bristol @iBristolPeople @BristolArtCo #clifton #bedminster #southville @thebristolmag @CliftonLifeMag
#
# @bexmader recently I got a #wicked t-shirt! ? you like it? ?
#
# RT @giuliaccia: The colors of #borghetto and the gloomy sky! #tuchini #CarnevaleIvrea
#
# RT @KiM_96I: С днем святого валентина всех празднующий с инетом. Ну или с парой.
#
# RT @HighburyClock: Arsenal's first-team train at a gloomy London Colney this morning. Hopefully, the Emirates won't be gloomy tomorrow! htt…
#
# RT @mrscena254: Can we just take a moment and realize how long my hair was ??. #depressed #throwback
#
# RT @boredpanda: Gloomy Watercolor Cats Slowly Bleeding Into The Paper (12 pics): #watercolorpainting #cats
#
# И как говорил мой дорогой товарищ:"лавки-скамейки"
#
# RT @JosephMRyan1: RT @smjgourmet: ????????? #HappyValentinesDay Back Atcha From Cold & Gloomy NJ ..@jcandlou7 @Dodarey @JosephMRyan1 http:/…
#
# RT @heyingridnilsen: A little color on this gloomy day in the city. I feel like a ?!!!
#
# @Rosalynchapman Was fully committed to my health today & went to full body blast class...still recovering!!! #aching
#
# How My Display Looks After Calibration #Baffled #Professional #Snob #HomeCinema
#
# RT @harbellot: #AvaGardner bebopper ! - with #Dizzy #jazz
#
# RT @Hystericalx: This is my snapchat ? : complicated94 #depressed #suicidal
#
# #AssadHolocaust the world grieved at the burning of asoldier and they silence at the burning of hundreds of civilians
#
# Our hearts are sorrowed our souls are grieved #JusticeForMurtaza
#
# Stay tuned! #teammazon #KG27 #zealous @Wizza27 @HockeyAustralia @PunjabWarriorHC
#
# RT @RheaFrancani: My EP #IWantYouToKnow comes out Feb 10, 2015! It also features my single #Dizzy- Get ready, can't wait!! #EP #Feb10 http:…
#
# RT @southernpride50: SAFE 2/12/15. ADOPTED. TY. HAPPINESS ROCKIE??URGENT 2/3/15.NYC. ROCKIE. https://t.co/ujoxXJpIpd.
#
# RT @6CDM: Happy #valentinesday dear @AllisonMcAtee I hope you have an #amazing day full of #love and #happiness ??
#
# @KirstenCollinsM Pretty girl! Very beautiful! Happiness to you! And Happy Valentine's Day!
#
# RT @southernpride50: SAFE 2/10/15. ADOPTED. TY. HAPPINESS LILY??SUPER URGENT 2/10/15.NYC. https://t.co/gbD7DshAkT.
#
# #Rain by DJLee - #Atmosphere #Barren #Branches #CloseUp #Cold #Dark #Green
#
# "@ItsFoodPorn: Strawberry & Nutella Crepe my happiness ??
#
# RT @FootyVibez: All I need for valentines is the happiness of playing soccer ??
#
# #Dizzy! Daredevil visits #Tuscaloosa and climbs the railroad trestle over the Black Warrior:
#
# RT @adoreaboutluke: luke smiling is SO important to me my tummy flips with excitement joy and happiness just by knowing he is happy
#
# RT @southernpride50: SAFE 2/11/15. PULLED BY SECOND CHANCE RESCUE. TY. HAPPINESS PINK??SU 2/9/15.NYC. https://t.co/UWlfgna6Fp.
#
# This is happy good evening meet ; With such a fine scene sweet.
#
# RT @ThaStonerNation: Happy valentines day.
#
# RT @damnjusteen: Happy Valentine day from us ?? @tilyouoverdose
#
# @hugomaciasmacot ? ? Happy Valentine's Day ? ?
#
# happy valentines day to me from me ??
#
# Happy Valentine's Day @LilKim!! ???
#
# RT @1GTurner: Last day on camp for me! Quality track session from the group. 132 x 400m from 9 athletes! #dizzy #altitudetraining
#
# @SaraRamirez HAPPY VALENTINES DAY ??I love you
#
# @LaRosaMendes Happy Valentine's Day ??
#
# RT @ESPNFC: Happy birthday to #MUFC forward Angel Di Maria, who turns 27 today.
#
# RT @alina_116: HAPPY VALENTINE'S DAY!
#
# RT @DEMImyLIFE20_8: I want a hug of @ddlovato because I feel so bad right now #depressed
#
# RT @CollinsHarriet: Extremely Happy with my progress didn't think my #quads could get any bigger @mym_apparel @gnc_co_uk @JSTJODIE
#
# RT @BrooksBeau: Happy Valentine's Day babes.
#
# RT @5SOSAlert: Happy Valentine's Day to me
#
# Im heated Rt“@kylegotjokes: White people can never just chill
#
# View from #theshard only floor 32 and am feeling #dizzy lol
#
# Check out this amazing deal! Brand New Singe/Double/King Heated Electric Blanket 20% off! Now only ?9.99!
#
# RT @therabbithaus: The boys are having a pre-dinner, heated pool swim at @TsogoSun #SSCullinan (mommy's having a cosmo)
#
# #colorsplash_bw #zealous Chocolate #university online: With chocolate classes from Choc
#
# RT @Chrissybshow: Black swan. You may feel different frm others cos u r #depressed but u r still beautiful & unique. #beatdepression http:/…
#
# Heated af. My second pair was supposed to be skipper blue, not glass blue
#
# RT @GarthCripps: Migrant #traditionalfishers living on the edge, Nosy Manandra, #Barren Isles, #Madagascar
#
# RT @GrahamMcCormick: With @MercedesBenzCDN #4Matic & a heated steering wheel it's #Snowproblem getting around today. @VictoriaStarMB http:/…
#
# BEAUTY : #66781 NEW Mastex Professional Heated Beauty Booties Feet Therapy- White (MX-25) …
#
# snowing outside but we can't be bothered - thawing out indoors. Best heated pool in the city. @FSPhiladelphia #philly
#
# RT @RevolutionSyria: Help the helpless. Tweet & retweet for #Syria. Don’t let evil get its way. #AssadHolocaust
#
# Another @DaveMoran89 penalty flies past a helpless goalie (after bouncing twice) 3 out of 3 for him now #letissier
#
# #jbb #nature #winter #snow #ice #barren #frozen
#
# Happy Valentines day Ajit???????khush rehna??
#
# RT @NRO: Professor Argues That College Students Are Helpless and Need ‘Dictator’ Teachers
#
# RT @taylorswift_re: RETWEEt if U HAVE A HOPELESS CRUSH ON SOMEONE u CAN NEVER CALL URS #TaylorSwift
#
# RT @5sos1dizzle: ? RETWEET if U HAV A HOPELESS CRUSH ON SOMEONE YOU CAN NEVER CALL YOURS 5sos5
#
# RT @SaatchiArt: Happy Valentine's Day! ?? Here is "Hopeless Romantic" by @MarkPoseyArt
#
# RT @Lab2Palestine: British consul @CGAMcPhail "horrified" by illegal Israeli settlements on visit to West Bank http…
#
# Atleast my boyfriend understands me. #depressed #parentsdontknowshit #clearly
#
# Don't tell me I'm not the only one who does this. #selfiewithdogs #doting
#
# RT @kScodders: Here's a picture of me looking horrified because I've realised there's griver jizz on my shoulder.Also the dvd's out http:/…
#
# “@biancalsanchez: @gean_samantha how about dear god no? im horrified
#
# Money never hurt my feelings #HappyVday
#
# RT @kdotsee: @MartyMcNasty you gotta let that hurt go.
#
# #depressed #depressionquotes #death #depression …
#
# RT @P0iS0N_R0YALTY: Hurt Hoes Come Take Shots with @kyngpin__ @shycarlito23 & I Tonight! Shots and Jizzles on Mee??
#
# RT @thugliest: An actual women people should be idolizing Angelina Jolies talent and beauty is just as beautiful as her soul
#
# Chegaram nossos novos cart?es =D #agenciaDoting #cart?es #doting
#
# At -- #drugs #alternative #blithe #dark #depressed #depression #grunge #insine #pale #para…
#
# RT @Brick143: Progressives idolizing the tactics of HAMAS....adults raising baby racists
#
# #trashcomics lmao dick, so incensed. HOW COULD THAT HAPPEN *flops all over the furniture*
#
# RT @_metafizik: Getting really incensed w/ the GOP's public displays of disrespect to the POTUS & America. Karma's due.#UniteBlue #P2 http:…
#
# Absolutely incensed by this cynical 50 Shades/Valentine cash-in at Tesco
#
# Great view even from the Gods @TRPlymouth #wicked
#
# Best girl. Had a rough week. #barren
#
# It's about the charm, the attitude, that smile... and suddenly you're infatuated! #HappyValentinesDay #BeMODE #love
#
# I'm still not over these I'm so obsessed and in love and infatuated with Jade
#
# RT @_RickyLance: NEW MUSIC: Check out my new song Infatuated w/ @OfficialJeuice streaming on @DailyLoud - https://t.co/oX6nZTNWnO
#
# I think it's safe to say I've never been so infatuated and in love with someone. Never want another Valentine ???
#
# @MrsRachelHudson (-) ella- Te quiero....- susurra mordiéndose el labio inferior mirándola a los ojos-
#
# Was an exciting start to the week with good news yesterday #ecstatic
#
# Q: Which vascular territory is infarcted here? ANSWER: #FOAMrad #FOAMed #radiology
#
# RT @deeply_drowning: #Sad #Sadness #Lost #Lonely #Hurt #Broken #Depression #Disorder #Depressed #Selfharm #Selfhate #Quotes #Suicide #Hope …
#
# kahraman was infuriated here ?
#
# RT @LennoxLewis: This is what many black Americans see and become increasingly infuriated! Change is needed!
#
# @SBNationNBA This is crap, where's the luv for the west coast?! Infuriated ?
#
# Daughter is infuriated by her father's wrong lyrics to 'Frozen':
#
# @rustyandalex sets the new BOYS STATE SWIMMING RECORD in the 200 IM 1:49:20
#
# #Whatever is begun in #anger #ends in #shame
#
# Just learned Girl Scout cookies are now $5 per box. #APPALLED #DISBELIEF #INFLATION #FormerGirlScout
#
# I am extremely honored to announce two artists coming to #eauxclaires on July 17 & 18: @DOOMTREE @blindboys #ecstatic
#
# Erdo?an ve Davuto?lu ?zgecan'?n ailesini arad?
#
# RT @jessicabrunnerr: NEED MORE GUYS LIKE KEVAL IN THE WORLD @ITzKevalz ??
#
# RT @NRBConvention: Joel Rosenberg to Speak at #NRB15 Convention in #Nashville Feb 23-26! @JoelCRosenberg
#
# RT @WW1DUpdates: Niall with some fans at a club in Melbourne tonight -N
#
# RT @Number10cat: The Government wants to cut benefits to obese people. In related news:
#
# I WAS TAKING SELFIES AND I PUNCHED MYSELF IN THE FACE?!?!
#
# RT @PrettiiRickii: Allyah, look at a picture from kiddie carnival in Trinidad ??????
#
# RT @rainbows_vodka: Don't you dare.... #ana #mia #sad #thinspo #skinny #depressed #depression
#
# #ANIMALABUSE #TORTURE #Beaten #Bound & #Burned #TORONTO #PUPPY #TORTURE we offer $1K #REWARD
#
# RT @adxentures: Wanna visit black beaches in Hawaii ??
#
# RT @brasswax: #BookCovers: #Ecstatic #Collaboration #NumberNext @PJManney's "(R)EVOLUTION" #47North
#
# RT @VeryOldPics: Teenagers on a date in the 1950s
#
# RT @DennyJA_WORLD: To love is to stop discrimination, in Indonesia and in the World. RT if you agree. #HappyValentine
#
# RT @ChadJordan23: When you confidently yell out the wrong answer in class...
#
# RT @s04_en: FULL TIME: #Schalke are beaten 1-0 in Frankfurt. #SGES04
#
# My sister who's in Drankenstein prison 2day tchg entrepreneurship to break the cycle of poverty for men in S.Africa!
#
# RT @___Danno: Innocent until proven guilty? #MacKay's "murderous misfits" quip could cause mistrial #cdnpoli
#
# RT @catbreedsWpics: loveucats: #ana #sorryimnotperfect #depressed #drowning #deb #cat IG > imaakim
#
# RT @gianniii__: 2 types of girls in philly?????
#
# #ANIMALABUSE #TORTURE #CANADA #PrinceAlbert #SASK. We offer $500 #reward #beaten #frozensolid
#
# Putting the finishing touches to a 700m2 @FreemoveUK #parkour park in Madrid - launch event coming soon! #PKGenSpain
#
# Will Kate make it out?
#
# Other fans are disappointed && I'm over here #ECSTATiC!! REFUND that $$, please && #THANKYOU ??
#
# RT @S1dharthFever: Awwwwwwwww that intense looks ??
#
# “@FIirtations: fifty shades of grey looks intense must see! @kea_heyy @_kelltastic_ @ColleenJervis
#
# RT @ltsGREYSquotes: this was the most intense episode EVER ??
#
# RT @tbhfuckoffpls: 50 shades of grey looks so intense
#
# Ghetto Wrap Job #ThanksMom #Stabbed
#
# ? #depressed #depression #anorexic #anorexia #ana #bulimia #bulimic #mia #ednos #ed #eatin…
#
# “ Because writer is too intimidated for asking to RP. ”
#
# Heeheehee... Confliiiiiict. You go, Dipper! Don't be intimidated by that guy!
#
# #Meerut Shocker pics: #Lawstudent #raped, #beaten, dragged for refusing #surrogacy #UP Update
#
# RT @AlbanMaginness: Found out that RNU gratified and vandalised my constituency office overnight- the SDLP will not be intimidated
#
# RT @rosemaccork: #Denmark Prime Min intimidated by #China attacked fr not meeting @DalaiLama #Tibet
#
# RT @jungkcook: Namjin is freaking real, your arguments are invalid..
#
# Ready for my first full week of training w/the premier team! #Ecstatic #CarpeDiem
#
# СРВ - донашивает джинсы Валеры.
#
# RT @LamboHersey: “@ABC: JUST IN: Punxsutawney Phil sees his shadow, #6moreweeksofwinter #depressed
#
# RT @DepressedDarth: Chewbacca punching Hitler, your argument is invalid
#
# RT @MissGal__: "@CoolAssShaee: ???? wtf this bitch need dr.miracle ???
#
# Yes, Johnny Rotten is a Gooner. Your argument is invalid, Spud fans. #COYG #FOYS #ArsenalFC ##Atid
#
# PerezHilton : .Madonna's Isolated #Grammys Vocals Leak & PROVE She's Still The Queen! …
#
# Only 6 months until 5SOS performs at @ThePavilion_TX !!!! #RockOutWithYourSocksOut #Ecstatic #Pumped ?????
#
# Far from beeing isolated, the Tibidabo's amusement park Ferris wheel rises 500 meters over the city of Barcelona by…
#
# RT @AmazonWatch: #Slimy17 @petrobras is exploring 4 oil in 1 of most isolated parts of Brazilian Amazon #divest http…
#
# RT @LeGourmetGirls: Sublime Sachertorte Dark Chocolate Jaffa jovial joy on a plate-Chic-Ragous delight #Foodporn htt…
#
# RT @Ginger_Zee: Oh no! “@MFillionMD: @Ginger_Zee massive white out on I 90 Indiana near OH border. 90 shutdown. EMS arriving.
#
# About Being Judged #QuiltShow #QuiltFestival #Judging
#
# At #Costco gas, ever feel like your gas-pumping abilities are being judged by people behind you? #performanceanxiety
#
# "A heart is not judged by how much you love, but by how much you are loved by others." --Frank Morgan
#
# Kat just before she gets #beaten by Killer Sex in a #topless #submission #catfight.
#
# RT @HoweMaster: Coffee number one is "light" hearted but complex at the same time!
#
# RT @luxury__travel: A light-hearted look at the top 5 luxury travel trends for 2015
#
# https://t.co/tMlkHqlaBA Grown up #FlowerFairies of #childhood
#
# good night everybody ?. #Sad #depressed #untouc… htt…
#
# RT @DianeMaeRobinso: "It is truly a hilarious, light-hearted read that is a treasure on anyone's bookshelf." http:/…
#
# RT @RichardWiseman: Bloody hell RT @drhingram: A light-hearted moment from a children's bible there (via @andynyman )
#
# RT @dynamitefilm: A light hearted moment on set with our actor @IANMHARDING https://t.co/zW072r6dFX #dynamitefilm #tatesteinsiek #happy htt…
#
# RT @ShettyKiran88: 20km total today for #werun2gether in #earthathon, including #greenwich10k @RunThroughUK ?? #medal #run #ecstatic ?? htt…
#
# RT @jlist: My hobby: describing Madoka Magica to inexperienced anime fans as a "fun, light-hearted magical girl anime."
#
# It's been a year and a month of pure loneliness. You could say I've resorted to old habits.
#
# RT @WandiRard: ahhhh the sweet smell of loneliness is in the air today
#
# RT @beckvalleybooks: Who Am I? by @MeganCyrulewski 'is a raw and emotional story' reviews @Divatude #depression http…
#
# #letsgo #cancun #herewecome #yolo #ichtrinkgintonic #2chaoten #ontheroad #excitement #ecstatic #ballsohard
#
# música y vídeo estremecedores para quien quiera oírlo. http…
#
# #blue #eyes can't be #beaten
#
# Marooned in Fraggle Rock by David Young 1984 Hardcover Fraggles
#
# A big step we can take towards greatness is to stop asking permission. Th #depression
#
# I'm not stuck in the past. I'm marooned in the present.
#
# RT @JonErlichman: YouTube star @ConnorFranta reflects as @YouTube turns 10
#
# GRACE ELEMENTS FROM THE USA WOMENS SLEEVELESS RUFFLE TOP IN BLACK - SIZE MEDIUM > #Womens…
#
# RT @thedailybeast: Argentina's president could go to jail.
#
# RT @DailyNewsEgypt: Barclays Egypt pumps EGP 250m for small, medium projects through 2015 -
#
# Gmail Support & Help :-https://t.co/GQhdp3vzKz
#
# 16" Devoucoux Socoa Saddle - 2009, 0 Flap, Medium Tree
#
# RT @Journalism2ls: “300 Awesome Free Tools (for your own News Startup)” —Voicester
#
# #ANIMALABUSE #TORONTO #PUPPY #TORTURE WE OFFER $1K #REWARD puppy #beaten #bound #burned
#
# #lonely #suicidal #ana #selfharmmm #worthless #addie #broken #single …
#
# Oh, ya know, no big deal. Just my senior pictures is all. #ecstatic #thankful #obsessed
#
# TONY PARKER T SHIRT san antonio spurs SMALL ... - - See More At
#
# RT @fcain: How can we still see the Big Bang? - https://t.co/PTUIVprKcA by @StartsWithABang via @medium
#
# WOMENS MARILYN MONROE WHITE DRESS HALLOWEEN OUTFIT COSTUME MEDIUM M 8 10 WIG
#
# New Womens CHAUS Short Sleeve Black White Lace Shirt Top Size M Medium
#
# Photos: #Photographer got a rumble in the #jungle as he was #beaten by 30-stone #gorilla
#
# A fabulous evening with @The_Kingsolver . Thanks to @Hollard for making a very special evening possible. #elated
#
# RT @Junwool: pixivに投稿しました 委託開始 #pixiv
#
# RT @sophiebadman: LOOOOOL HE MOCKED IT
#
# RT @Tumblrians: EVERYBODY ELSE IS SHOCKED AND MORTIFIED AND THE QUEEN JUST LIKE “BUT THE PARTY HAS ONLY JUST STARTED MOTHERFUCKERS”
#
# Hate snow...I hate the snow. Fuck.winter.
#
# RT @dreamsskinny82: Why can't I b like this & then people might actually want 2 b with me! #thinspo #ednos #anamia #ugly #depression http:/…
#
# RT @BolverkGTM: The Valentine Patchy gets better each year.
#
# RT @dancu: #LoveLive Kotori, Happy Valentine's Day
#
# My mum was pissing herself at this card in the middle of Clintons I'm mortified
#
# My own little space inside a humongous 4 sets Studio.... #recognition #elated #happiness
#
# Neglected For 50 Years, What 2 Guys Found on This Farm is...
#
# RT @Gingeahoy: tiny guy on A5..inspired by a recent doodle I did for @MollyWallisArt (wihch I neglected to scan!)
#
# RT @anasbutterfly99: Not thin enough. Not smart enough. Not tall enough. Just not good enough. #depression #ana #anamia
#
# RT @PLTC_PastLives: Warning: Disturbing video but needs attention! #Dogs #beaten to death for #leather. #abuse https://t.co/8QgXBXzuLq http…
#
# RT @robertasmithnyt: Also at Clyfford Still Musuem, astounding earlyish work whose data I neglected to record. #OffSiteTweeting
#
# RT @DogRescue2014: TAG needs your vote! ?500 prize will help save abused and neglected dogs and cats in Turkey! http…
#
# @dukecoachdj wolves rarely leave the pack unless exiled or ostracized #LoboTough
#
# Donage twins :D and Barlowen ^^
#
# #Elated?RT @warblerscon: @LetLoveInEvents is glad to announce the second guest of the #warblerscon: @DominicMBarnes!
#
# The Force of AI is weak in this one but #StarWars - Jedi Knight II: Jedi Outcast is still fun. Q3 engine FTW!
#
# COLLEGE KIDS OVER A“PARKING SPACE“Bullshit,ITS A HATE CRIME?
#
# Rough night #black eye #beaten #fxmakeup
#
# "If you are not outraged then you are not listening"
#
# RT @TRobinsonNewEra: Will these lot in the UK be outraged by the killing in Denmark, and protest? No!
#
# @jessicavaca_ @Josiemajor24 #Overjoyed for #ValentiesDay can't you tell from the expression
#
# "@HoHoHozier: Armani and a man bun; lethal combo Oh my Gosh! #Dreamy #Excited #Elated #Hungry .. I can go on and on.
#
# RT @IndianaCSmedia: #PraiseTheLord ...He healeth the broken...#HeartMonth #hearthealth #depression
#
# RT @KimXiFTW: “@LettemeLove: Truly overjoyed!!! #tearsofjoy #happyhearts #KimXi??? Kimmy,you're one blessed lady! ???????
#
# RT @therealtabrett: Oren won best short film at #hriff .so incredibly stoked .thrilled and overjoyed.love to all involved @The_Oren_Movie h…
#
# RT @SFnewsnow: "I Can't Believe It!": Woman Overjoyed at Sight of Obama in SF #sanfrancisco
#
# 2/14/51 Larry Milbourne-pride of Port Norris NJ-born. Overjoyed & proud as hell member of 1982 Twins, previously NYY.
#
# RT @ChaosChloe: #Chaotic Mind!! That was really heart felt. Thank u @SPARCEO
#
# RT @Gifts_of_Cheer: Squealing with delight, kids were overjoyed to receive Gifts of Cheer today at @ReadingHosp!
#
# RT @DannyBurgessFL: We are overjoyed to announce that our little Addie is going to be a big sister! ETA 8/2015. #ValentinesDay
#
# He drew on the glasses :') overjoyed and filled w love
#
# RT @otrbristol: 21 comics that capture the frustrations of #depression: RT if you can relate to these!
#
# "I can't believe It! That was on my bucket list!": Woman overjoyed at sight of @BarackObama
#
# Sprayed with iodine. They sent small replacement top and it fits! Even with an undershirt! #elated!
#
# “@_AmberWebb_: The only Valentine I need in my lyfe. ? I'm obviously overjoyed by this
#
# It's been five years, but I'm more than overjoyed to wish you a happy 23rd birthday, I love you baby. Rest easy. ???
#
# RT @peta2: RT if you are OVERJOYED that #UWMadison ENDED its cruel cat experiments! #StopAnimalTesting
#
# London swamped by #intolerant #uncompromising #belligerent #MuslimScum. #Britain is #dying & its #death is immanent
#
# RT @camilacabows: "my therapist taught me to start thinking of my anxiety as my panicky friend. it’s working,"
#
# @SZTheGod IM PARALYZED FROM LAUGHTER ??
#
# RT @AlterThePress: EXCLUSIVE: We've teamed up with Against The Current to premiere a NEW SONG titled #Paralyzed! htt…
#
# Flexible spinal cord implants will let paralyzed people walk
#
# #frozen #cold #canada #winnipeg #natural #photography #art #snow #ice #deserted #shed
#
# RT @KTLA: Alabama police officer arrested after video shows him slamming grandfather to ground
#
# RT @arifs072: Our baby Tuleen who was paralyzed after being run over by a settler finally took few steps after months of rehab.
#
# Only a @idahocafe caramel triangle can cancel out the misery #amongstwomen #bleak
#
# Go Hope Go! #ClinicalTrials #Paralyzed #dogs
#
# Cop Charged With Assault After Man Left Paralyzed
#
# You are smart driven adventurous passionate powerful excited and a little nervous
#
# RT @mahbob67: Passionate speech by Honorable former MayerGiuliani #Arizona #Phoenix condemning #Iran'ian Regime's #Nuclear program
#
# May your love be passionate and kind.
#
# RT @IgniteOruba: A passionate novelist, a public speaker, and a fitness trainer, wait for @WaadArif at #IgniteOruba2015 on Feb 21st!! http:…
#
# RT @NHAparty: Be passionate about a podiatrist #loveNHS
#
# Jake saw Sid score in person tonight for the 1st time! #elated
#
# RT @OnlineBaddies: she's stunning ?
#
# Have you seen the Award Winning Dreamgirl Collection (up to Plus size 24) Retweet 2 friends
#
# Winters day by the sea #sun #blueskies #sea #felixstowe #walk #warm #deserted #waves
#
# RT @TemptationsCats: Thanks for sharing pics of TEMPTATIONS’ passionate feline fans! This #PackAttack of the Week star is Murphy!
#
# RT @LinkedInMktg: 5 Passionate Posts from Top Marketers Who Love Content Marketing: @DaveKerpen @bethcomstock http:/…
#
# @NHL I love the Dallas Stars for, according to Brad Lukowich, the most passionate fanbase in hockey! #HockeyLove
#
# Deals : #7557 Navajo Sterling Petrified Wood Agate Cuff Bracelet & Necklace Set ca. 1970s …
#
# Took Mikaila to RJ, she was petrified to jump at first but it all worked out?
#
# Painting for the Petrified #painting
#
# 65mm PETRIFIED WOOD SPHERE Rock Stone Polished 2.5" 316 Grams
#
# #195 Petrified Wood Gemstone .925 Sterling Silver Overlay 2" Pendant
#
# Can't.Wait.For.Tomorrow ASSJHCXBSJCHJS #elated @Jeemwell @cruzmarichu
#
# There may be times when we are powerless to prevent injustice, but there must never be a time when we fail to protest
#
# I am powerful. Alcohol is powerless.
#
# RT @Steve_Kells: We working #MarieClaireMagazine
#
# RT @501stLegion: RT @501NEG: 2 things a Stormtrooper is powerless against in armor, low hanging objects & this @501stLegion @FISD501st http…
#
# "Powerless and i don't care it's obvious"
#
# Still reeling from #ConstantineFinale last night that today I'm rocking my tench coat! #SaveConstanstine #Constantine
#
# Reeling him in to...DNOW!? This is the last week 2 register. $75, register @ #DNOWinvitelines
#
# #colorsplash_bw #zealous Pr #powershot aged and expired domain software: Converts. Anal
#
# Look at all the people who get more money than us. #studentathletes #bitter
#
# It FINALLY arrived and I'm SO #elated! Farewell #iPhone4S & Hello #iPhone6 !! #backorder #fb #AT&T #RadioShack
#
# Relocation or Adaptation: Earth Home Project Brings Relief to Pakistanis Reeling from Floods
#
# Reeling him in better be a joy. #fishing #surfcasting #surffishing
#
# RT @misterdickison: @Castleproud @CastlebrookeMC Still reeling from some crazy musicianship! Start rehearsing for the next coffee house! h…
#
# RT @Belterra: We're reeling in something amazing this February called #FishermansKeep. See you for dinner!
#
# If you're scared of being rejected just send one of these
#
# RT @globalnews: .@allisonvglobal on rejected flags (Images via globalnews1 @Snapchat) #flagday #Flag50
#
# A deserted station in Chicago, USA. Good shot by @lostunder21 #deserted #abandoned #Nobody #station #night #chicago…
#
# RT @ANNZac: REJECTED ON THIS OF ALL DAYS
#
# Cayendo copos casi imperceptibles suficientes para hacerte sentir esa felicidad estúpida e infantil #snow #elated
#
# RT @ryansparkytay: Looks like someone got rejected... a moment of silence pls
#
# RT @INSenDems: Sen. Lanane speaks on SB 1 which would remove Supt. Ritz as chair of #SBOE. #iStandWithRitz | http:/…
#
# Never Forget this! Hillary Has forgotten it! never once say SORRY no remorse!
#
# Does anyone find the cover of @nypost offensive and distasteful? #Appalled #bobbikristina
#
# RT @FleetPolice: #ValentinesDay. If your heading out for the night make sure it's not ruined with a room for one at one of our B&B's. http:…
#
# #WhyImSingle @justinbieber ruined my life. But in the best way possible ?
#
# 037 / 365 Engageante by ... - #Abandoned #Beauty #Carpet #Castle #Decay #Deserted
#
# RT @BlSCUlTS: weird Twitter has ruined my sense of humor, I laughed at this for 10 mins
#
# Rt GrootBot: I am Groot. I_AM__GROOT_: RT Whatacuteface: Cant believe these guys ruined this dogs selfie ?
#
# ...
#
# Just waiting for the sis then off we go! Gym time ?? #excited #happy #workout #FeelGood
#
# #Kjell Ola #Dahl - #False #Apparenze (#Repost)
#
# RT @laurentbaheux: Cheetah's Eyes, Namibia 2004 ? print 40x40cm from 180€ - contact@laurentbaheux.com - #Wild http:…
#
# #broken #flat #edges #shuffle #white #thin #gram #grain
#
# Ask protestors y DL's lying?
#
# RT @JacobyShaddix: @shaddixlover13 love this!!!! #paparoachfansarethebestfansever #PAPAROACH #LVRSRLNTCS @paparoach @lvrsrlntcs #FEAR … htt…
#
# RT @JacobyShaddix: Not unpacking just re packing. Tour life #FEARtour #FEAR
#
# RT @SCalCS: Infectious #health? What do you want to catch? #contagion #fear @csinmichigan @NewsHeraldMI
#
# RT @TGSNTtv: The only #evil thing about #Hitler was maybe his shorts. Learn the #truth
#
# RT @Julie_Garmon: A Secret Place in My Heart #fear #amwriting #Trinity #prayer
#
# #game #girlgamer #fear #GTAOnline #GTAV htt…
#
# Hammered myself again... #fitness #aching #NoPainNoGain #homegym #boom
#
# New @paparoach hoodie is so comfy! A must have #FEAR #Merchandise #paparoach
#
# #tattoosday #fallschurch From #fear to confidence: This Method For Developing Self-conf
#
# #art #arte #photo #artist #retrato #MujeresPoderosas #miradas #Photoshop #design #horror #fear
#
# Back to the hotel and @ColinBland78 is on his arse AGAIN!!! So much for BCFC fans! #Feeble
#
# #rwilly @rwillyofficial #hellagrip #smith #feeble #f…
#
# #zealous #newyearsday Family #friendly fat burning meals: Quick, Healthy, Family Friend
#
# #finished !! Plus de photos demain :) #art #painting
#
# "@asabfb: #alevels #finished LITRO ME WITH GCSE'S
#
# RT @Lydia177Wattpad: 314 pages later...second draft of my first ever novel is completed! *insert heavy sigh here* #amwriting #finished http…
#
# @Cathy_Crawley how bout my cute little shed Cathy!!!!! #finished
#
# #finished #my #pallet #town #project #pokemon #yellow #version #ash #tomorow #i #start #ro…
#
# #happy #black #white #bedroom #selfie . #just #finished #homework . by brendan_de_faria
#
# RT @Nelsyncube: I don't know kuti ndodhii #finished
#
# RT @identidex: Have you #finished setting up your #profile? Check out our #GettingStarted guide to get the most out of #Identidex!
#
# RT @MinusIndustries: Day 365: #365PROJECT: 365 Days of 30 Minute Drawings #Yeg #YegArt #YegArts #TheEnd #End #Finished #Finale #Fin #MINUS …
#
# #Finished #LowPoly #Portrait #Art #Artwork #Design #Illustrator #Adobe #Photoshop
#
# #FLAWED “@ReadyForHillary: "Who run the world? Girls." #GRAMMYs
#
# RT @Parents_Recover: #beautiful #flawed #imperfect #WUVIP
#
# RT @QueenKyleNicole: #YouAreBeautiful #flawed to #perfection #quotes #christinaaguilera #musiclovers
#
# F14 WED ?1000 Can stand for FLAWED/ FEBRUARY 14TH WEDDING. #flawed #feb14th #valentinesday
#
# #selfharmmm #suicidal #staystrong #sad #anerexic #flawed #suicide #bands #tears #sadness #…
#
# “@conspiracyimage: Then how did Rose throw it in the ocean in the end of Titanic? #flawed
#
# RT @JoshuaTreeNP: Shall we take it for a spin? There are several old cars along the Wall Street Mill trail. #cars #abandoned #hike
#
# Upando pq né, ficar parado n?o da xp #forsaken
#
# Come see #NewWriting at @The_New_Theatre by author of #Forsaken @gerardlee10 runs until Sat 14. @writing_ie #Magic
#
# rotten bastard knows full well his missing jaw freaks out the living #Warcraft #forsaken
#
# #pic by (me) :)#gothic does not mean #evil, #art #photography but a #photo can say almost anything you want it too
#
# #AsILayDying #Forsaken #Music - We found "As I Lay Dying" - "Forsaken" for #free on audiom…
#
# ONE IS NOT ONESELF by #Forsaken author @gerardlee10 #MarkORegan #PaulaGreevyLee #RonanMurray @The_New_Theatre
#
# Greeted by strange children at the atm #antibanter #frightened #poverty #sorrow #yourbalanceis13cent #familyfun
#
# Hello beauty! ? #guinea #pig #sweet #rodent #shop #with #animals #so #cool #blond #bangs #hairstyle #frightened #bl…
#
# Wednesday: High pressure remains in charge yet again. Staying dry and cloudy in most places. #gloomy
#
# Yesterday's #gloomy gardens; will it be brighter today? #ntmidlands
#
# sums up my free time #exploring #adventuring #walking #train #tracks #traintracks #gloomy #grunge #hipster #punk
#
# #gloomy #piano Chinese #secrets to sarcoidosis healing: An ebook that reveals why there
#
# This is a very Manchester sky! #gloomy
#
# Need a #desk #lamp for the #gloomy winter evenings? Come to @BusinessShop07 #haywardsheath today!
#
# #broken #gradient #noedges #raster #grain #colorize
#
# #gloomy #piano Console #unlock - guide to unlock the nintendo wii *hot niche: Guide For
#
# "@foodandwine: These gooey, fudgy, caramelly brownies are here to ruin your diet: #Evil
#
# #gloomy #study #in #historic #corruption #Thomas
#
# Just catching up on Broadchurch. #cheerup #mightneverhappen #gloomy #bloodyhell
#
# #fashiongirlslikeus #gloomy Coolbeat #audiobooks: Award Winning Coolbeat Audiobooks Pub
#
# RT @TatianaMPhoto: Special unreleased photo exclusive to Twitter only 5/6/14 Model: Mark #madscientist #Psycho #Crazy #Evil #Crazy #Eyes ht…
#
# #Gardenofthegods #colorado #breathtaking #PicsArt #naturephotography #ScenicStops #winter #gloomy #stillbeautiful
#
# #me #Brooklyn #girl #gloomy #grunge #band #bass #darkness #music #musicians #live #cool #c…
#
# @GAMEKeighley Try sleeping in this room you would have nightmares! #grim #sceneofacrime
#
# #Grim band logo of the day: Sabbat
#
# RT @BRAINxTRUST: #Grim band lofo of the day: @BioCancerThrash
#
# #Rain by DJLee - #Atmosphere #Barren #Branches #CloseUp #Cold #Dark #Green
#
# #TVOvernights: #TheWalkingDead returns, ramps up the tragedy, nets #FOX 582,000 viewers #grim
#
# @GrimsToyShow I so getting this Pre-Order using discount code #GRIM to save 10%
#
# RT @MarayLiverpool: left to right: @italianclubnews minsky's @boldstcoffee and us! Early 90s, #grim!
#
# “@Chris_Smoove: I pulled this beast! #RealLockerCodePulls #StopLyingNoobs #RetweetGameCheese #burned @Ronnie2K
#
# #Life isn't about pleasing everyone. Don't let the opinions of others get in the way of your #dreams or #happiness
#
# RT @GarthCripps: Migrant #traditionalfishers living on the edge, Nosy Manandra, #Barren Isles, #Madagascar
#
# Like Danbilzerian ???? #Danbilzerian #with #special #friends #mombaza #fossbell #happiness #danbilzerian #boom #sex…
#
# Don’t get #burned. #hotseat #mobile #Tuesday
#
# RT @24k_extribeldh: E-girls CW記念個人ヘッダー Happiness編 1 #Egirls #Happiness #COLORFULWORLD #私の画像加工嫌いじゃない人RT #無断使用禁止 #使用?保存RT
#
# Don't take life so serious... #life #live #serious #happiness
#
# RT @UniverseVibe: May you glow with #happiness :) :* ?
#
# #customers #free #healthy #live #happiness
#
# Top 10 Happiest Languages #travel #happiness
#
# RT @Duaa_Zahi: "@benkubassek: Today's Be Attitude "BE BALANCED" #lifebalance #burnout #stress #happiness
#
# Mado even emails in an artsy way @MayCanTheatre @TACTICSeries #happiness #business #art
#
# RT @marshawright: Before you diagnose yourself as #depressed or with low #selfesteem, be sure you're are not simply surrounded by... http:/…
#
# RT @Reena24A: He defines #Happiness.. Bless his smile ?? #BarunSobti ?
#
# capture every moment even its a #goursouzia #superstition #ftou #broken #mirror
#
# Blog Post: #JulieSmith #WildOn #Nude #Gorgeous #Babe #Famous #Actress #Wild
#
# OtherWorld Buddha - #buddhism #buddha #zen #enlightenment #peace #joy #happiness Buddha, b…
#
# We've posted plenty of smiling #dogs before, but this one is the face of true #happiness
#
# "@SteveStfler: @dhodgy7 when you don't cook me dinner... #helpless
#
# RT @MiaLarson: Via @thejenwilkinson: Who are we if we are willing to hurt the #helpless ?" #Animalrights #Humanrights
#
# Evening #northeasthour how are we all today. I'm back fit & well after my first #cold #babies #helpless #fightingfit
#
# #Bu #sevda #bitmez #infinity #love #sad #helpless ●● #instagram
#
# Thanks @BarackObama , now the us is just a very #helpless #paintball #field. Shootings happening everywhere. #Gunlaw
#
# Kétségbeesetten várva arra hogy a tanulnivaló egyszercsak belemegy a fejembe hátha így k?nnyebben megy majd #hopeless
#
# This is what my business studies turn into everytime... #hopeless @yelyahwilliams @schzimmydeanie @paramore
#
# #StreetArtThrowdown Getting ready for disney night take two #disney #mickeymouse #excited #selfie
#
# CBPT Lake Forest is #comingsoon #getready #excited
#
# Team Surprise are paying a good old visit to the @PrinceAlbertSW for some old fashioned wine tasting. #Excited
#
# Heathrow bound. Fly early tomorrow morning! #excited #travel #southamerica #freedom #london
#
# A little more persistence, a little more effort, and what seemed #hopeless #failure may turn to #glorious #success
#
# guess I'll never meet @Harry_Styles. #hopeless
#
# RT @Wicked_Alchemy: ?#Wicked @Ruby_Goddess @sarriedj @forcuteangel @leon_flemming @melissacts1267 @lilhak420
#
# These are the types of thoughts you most definitely should NOT share on Facebook lol #horrified
#
# Thanks for ruining my day @lululemon ...3rd time wearing, a charm? #horrified
#
# This is still giving me the creeps #Horrified>
#
# @mzansiplates not sure how to caption this... #horrified
#
# #Horrified #BMovie #Victims #Playset #Swagshop
#
# Last nights gaming session. Only I am not pictured lol. #dnd5e #rpg #stillmovingin #chaotic #happiness #DMintheCorner
#
# This is so needed!! My body feels battered #aching #doms
#
# Best girl. Had a rough week. #barren
#
# So this is not even a quarter of my possessions #horrified #wankyfridaynightsorting
#
# @asap_tran what the fuck Totinos pizza rolls??? Lol #horrified #astonersnightmare #sostones
#
# Found in my @Pret wrap today... Is that a plastic bread clip???? Can't believe I just bit into this #horrified #ouch
#
# Listening to @nasty_CSA track....#Horrified #turnUp #abysmal #teamC'zzle #lame ...#lokishi
#
# suchimn: #Foodforthought #fadingout #horrified @itssylviaplath #quote #TweetsNow
#
# #abused #degraded #humiliated #humiliation #sm #hot #slave #sub -
#
# RT @KHMemes: #Burned #Shotsfired #KingdomHearts #KHMemes
#
# #slave #sub #submissive #exposed #abused #degraded #humiliated - [link removed]
#
# RT @katie_ed15: #mistreated #abuse #suffocation #sad #help #911 #bf #hurt
#
# Whew! Over 30min & #burned 300+ #calories w/ @Bowflex #treadclimber ???#progress #fitatfiftytwo
#
# #art #Toronto #heart #stiches #hurt #LoveHurts #oil #brokenhearted #brokenheart
#
# St Marys beaten in Sigerson Cup #marys #beaten #sigerson #cup #LebInfo
#
# @rjfapelacio nanggahot. Haha. :P #euro #impotent
#
# @DayanNajar feeling so #inlove,#crush #infatuated, #wird #enjoyable #melting... And moré!
#
# Recordando un poquito... #Infatuated #Memories #OrgulloSweetie @SWTCalifornia
#
# Wai borlog! Patiwakal laturrr! ? #Infatuated
#
# WE DONT WANT 2 KNOW YOR #GREEDY #EVIL GOD SAYS U GET MORE PAY YOR SPECIAL WE HAV OUR OWN #GOD SAYS WHERE ALL #EQUAL
#
# Get and eat the dirt off my walking boots you #inferior #submissive #dirtyboots that's you're breakfast!!!
#
# #Remember no one can make you #feel #inferior without your #consent
#
# #blackandwhite #photo #spika #triptoparis #in #baggage #киев
#
# #ANIMALABUSE #TORTURE #Beaten #Bound & #Burned #TORONTO #PUPPY #TORTURE we offer $1K #REWARD
#
# #vsco #vscocam #vscohub #vscobest #vscoonly #vscolife #vscolovers #vscofeel #instasize #instadaily #instaodessa #in…
#
# RT @ShoaibMalik702: Came back frm #CricketTraining #EarlyMorning #IndoorNets #Sundays #LahoreLions #Kit ??? #WithMyWhip #In #MaliksYard ? h…
#
# #TagStaGram #love #friends tagstagram #photooftheday #selfie #amazing #followme #follow4follow #like4like #look #in…
#
# Don't feed the #evil #Givelove #Feellove and #belove
#
# #Monster #who #raped #&amp; #burned #8 #year #old #boy #found #guilty #of #murder Click here:
#
# At Pittsburgh IAP, the skylight (above) always makes me think of this (below) #INvalid
#
# ???? ..... ??????????????????? ????????????????? ???? ????????????? .... #invalid
#
# #ANIMALABUSE #TORTURE #CANADA #PrinceAlbert #SASK. We offer $500 #reward #beaten #frozensolid
#
# #Loneliness #Divorce #Mentalhealth #HIV #Cancer #Prostatecancer #confidence #Autism 0800 970 8696 #NonSexualEscorts
#
# #vsco #vscocam #bestofvsco #bestoftheday #sadness #loneliness #tears #travel #travelling #trains #v…
#
# So this happened... #strong #baby #JustLikeMommy #ILoveHer
#
# My #Jasonvoorhees mask drawing ???. #FridayThe13th #Art #drawing #hashtag #EVIL @JasonLVoorhees @F13thFranchise
#
# RT @FriendsElderly: Loneliness is as big a risk to health as smoking. Help end #loneliness. Text BE A FRIEND to 70300 to donate ?3
#
# RT @SportsMemNet: RT please! Did you know...... #MentalHealth #Loneliness #Wellbeing #SportingMemories
#
# “THE #legomovie ” #DIRECTORS #MOCKED THE #Oscars !
#
# #Basketmouth #Claps Back At #People Who #Mocked Him Over His Feb. 14th #UK ... - ...
#
# Is the suspense killing you? Cause I'm pretty fucking pumped #overjoyed
#
# #Meerut Shocker pics: #Lawstudent #raped, #beaten, dragged for refusing #surrogacy #UP Update
#
# Getting back into it. #career #NeverStopNeverSettle #overjoyed
#
# Do you like #vampires?Forget #Twilight!"The addiction" 1995, #AbelFerrara, #movie about #good, #evil and #catharsis
#
# Let it snow,let it snow,let is snow ? It is snowing after 3 years ? #Overjoyed
#
# It's Adventure Time at McDonald's! #happyhappyhappymeal #overjoyed :D
#
# 1st post in #mindthegap blog series: #Paralyzed vs. #Stuck Hoping the difference #empowers U!
#
# How a #Drunk Driver is Changing the World #inspiring #redemption #paralyzed #wheelchair #jesus
#
# #Buffalo: Damone Lewis to be sentenced today for 2012 #shooting that #paralyzed 15 year old.
#
# #February #Winter #Rainy #Stormy #Windy #Wednesday #Evening #Love #Happy #Positive #Passionate #Calm #Fun #UK ?? ?
#
# #February #Winter #Rainy #Stormy #Windy #Wednesday #Evening #Love #Happy #Positive #Passionate #Calm #Fun #UK ?? ?
#
# diego costa 'This is Who I am'.#passionate
#
# #Wednesday #selfie #Younique2015 #younique #3dfibermascara #lipgloss #lovesick #lucky #eyeliner #passionate #bbflaw…
#
# RT @SamriddhaRay: @AshleyJudd @shailenewoodley @Divergent @AnselElgort Yes and I am a fan of the Divergent series too! #excited #fanArt htt…
#
# #February #Winter #Rainy #Stormy #Windy #Wednesday #Morning #Love #Happy #Positive #Passionate #Calm #M #Coffee ?????
#
# Kat just before she gets #beaten by Killer Sex in a #topless #submission #catfight.
#
# #February #Winter #Rainy #Stormy #Windy #Wednesday #Evening #Love #Happy #Positive #Passionate #Calm #Fun #Life ?? ?
#
# Get your Friday Night Look Sorted!! #Newin #LBD #Littleblackdress #Strappy #Plunge #Neckline #Mini #Black #Bodycon
#
# RT @N2312Neagoe: #love #caring #beautiful
#
# #February #Winter #Rainy #Stormy #Windy #Wednesday #Morning #Love #Happy #Positive #Passionate #Reading #Coffee ?????
#
# RT @ThatGuy__Kai: Honored to have Pittsburgh Pirates Consultant @CoachOTip speak to our ball club #passionate #relentless #ownership http:/…
#
# Genghis Khan ~ ily #relatable #king #passionate #yeet #yas #sogengrn @ap_genghis
#
# #February #Winter #Rainy #Stormy #Windy #Wednesday #Evening #Love #Happy #Positive #Passionate #Calm #Fun #UK ?? ?
#
# #February #Winter #Rainy #Stormy #Windy #Wednesday #Evening #Love #Happy #Positive #Passionate #Calm #M #Coffee ?????
#
# RT @bishopcarrollhs: Great @bishopcarrollhs students #caring #empowerBCHS
#
# Big thank you to all of the teachers who attended the #isabcpd15—so nice to meet with #passionate educators! @ISABC1
#
# @DBel67 #scared #veryscared don't be holding owt hot - we're coming nearer David...... #petrified ?!!!!!
#
# Completely #Unique #Petrified #Palm #Earrings Set In #Sterling #Silver #fossil #gift
#
# RT @headquarters: To be fair, everything makes me want to scream. #Anger
#
# #Fanghorn forest or #Alder #woodland up Glen #vorlich, #Lochearn. #petrified #forest #LOTR #Scotland
#
# Where there’s a whisk, there’s a way. #powerless #bakersgonnabake
#
# OMG. Well done #Eskom! 'Man dies during #LoadShedding' #Powerless
#
# Feelin' the love in here! #ValentinesDay #caring
#
# #blue #eyes can't be #beaten
#
# LA CHUCHA LOUUU TE CHUPO LOS OJOS..!
#
# #colorsplash_bw #zealous Remedios #herbales y tratamientos naturales: Remedios herbales
#
# betterfeelingfilms: RT via Instagram: First day of filming #powerless back in 2011. Can't …

# %% [markdown]
# 4. 将文本转为Word Embedding

# %%
def word_embed(txt, token):
    result = token.batch_encode_plus(batch_text_or_text_pairs=txt, 
                                     truncation=True, 
                                     padding='max_length', 
                                     max_length=32, 
                                     return_tensors='pt')
    input_ids = result['input_ids']
    attention_mask = result['attention_mask']
    return input_ids, attention_mask

# %% [markdown]
# 5. 统一数据格式

# %%
class NewDataset():
    def __init__(self, images, descriptions, tags, token):
        self.images = images
        self.descriptions = descriptions
        self.tags = tags
        self.input_ids, self.attention_masks = word_embed(self.descriptions, token)

    def __len__(self):
        return len(self.descriptions)

    def __getitem__(self, idx):
        img = self.images[idx]
        des = self.descriptions[idx]
        tag = self.tags[idx]
        input_id = self.input_ids[idx]
        attention_mask = self.attention_masks[idx]
        return img, des, tag, input_id, attention_mask

# %% [markdown]
# 6. 编写训练过程并绘图

# %%
# 训练的过程
def train_model(model, epoch_num, optimizer, train_dataloader, valid_dataloader, train_count, valid_count):
    # 交叉熵损失函数
    loss_c = nn.CrossEntropyLoss()
    # 训练与验证的准确率
    train_acc = []
    valid_acc = []
    for epoch in range(epoch_num):
        loss = 0.0
        # 训练集和验证集正确判读的个数
        train_cor_count = 0
        valid_cor_count = 0
        for b_idx, (img, des, target, idx, mask) in enumerate(train_dataloader):
            img, mask, idx, target = img.to(device), mask.to(device), idx.to(device), target.to(device)
            output = model(idx, mask, img)
            optimizer.zero_grad()
            loss = loss_c(output, target)
            # 反向传播
            loss.backward()
            optimizer.step()
            pred = output.argmax(dim=1)
            train_cor_count += int(pred.eq(target).sum())
        # 训练集准确率
        train_acc.append(train_cor_count / train_count)
        for img, des, target, idx, mask in valid_dataloader:
            img, mask, idx, target = img.to(device), mask.to(device), idx.to(device), target.to(device)
            output = model(idx, mask, img)
            pred = output.argmax(dim=1)
            valid_cor_count += int(pred.eq(target).sum())
        # 验证集准确率
        valid_acc.append(valid_cor_count / valid_count)
        print('Train Epoch: {}, Train Loss: {:.4f}, Train Accuracy: {:.4f}, Valid Accuracy: {:.4f}'.format(epoch+1,
                                                                                                           loss.item(),
                                                                                                           train_cor_count / train_count,
                                                                                                           valid_cor_count / valid_count))
            # 绘制准确率的图像
    plt.plot(train_acc, label="Train Accuracy")
    plt.plot(valid_acc, label="Valid Accuracy")
    plt.title("Bert AlexNet")
    plt.xlabel("Epoch")
    plt.xticks(range(epoch_num), range(1, epoch_num+1))
    plt.ylabel("Accuracy")
    plt.ylim(ymin=0, ymax=1)
    plt.legend()
    plt.savefig('BERT_ALEXNET.png')
    plt.show()

# %% [markdown]
# 7. 执行主函数

# %%
def main():
    model = bertAlexModel().to(device)
    lr = 1e-5
    optimizer = optim.Adam(model.parameters(), lr=lr)
    epoch_num = 10
    
    # 整体准备
    images = []
    descriptions = []
    tags = []
    emo_tag = {"neutral": 0, "negative": 1, "positive": 2}
    token = BertTokenizer.from_pretrained('bert-base-uncased')

    # 读取数据
    train_dataframe = pd.read_csv("./train.txt")
    for i in range(train_dataframe.shape[0]):
        guid = train_dataframe.iloc[i]['guid']
        tag = train_dataframe.iloc[i]['tag']
        img_path = f'./data/{guid}.jpg'
        img = Image.open(img_path).resize((224, 224), Image.Resampling.LANCZOS)
        img = np.asarray(img, dtype='float32')
        txt_path = f'./data/{guid}.txt'
        with open(txt_path, encoding='gb18030') as f:
            des = f.read()
        images.append(img.transpose(2, 0, 1))
        descriptions.append(des)
        tags.append(emo_tag[tag])
    
    # 收录词语
    for i in range(len(descriptions)):
        des = descriptions[i]
        # 空格分词，且去除Hashtag
        word_list = des.replace('#', '').split(' ')
        words_result = []
        for word in word_list:
            # 不是词
            if len(word) < 1:
                continue
            # 是网址或者用户名
            elif 'http' in word or word[0]=='@':
                continue
            else:
                words_result.append(word)
        descriptions[i] = ' '.join(words_result)
    
    # 图片与描述一一对应收录
    img_txt_pairs = [(images[i], descriptions[i]) for i in range(len(descriptions))]

    # 划分训练集与验证集
    X_train, X_valid, y_train, y_valid = train_test_split(img_txt_pairs, tags, test_size=0.2, random_state=42, shuffle=True)
    image_train, text_train = [X_train[i][0] for i in range(len(X_train))], [X_train[i][1] for i in range(len(X_train))]
    image_valid, text_valid = [X_valid[i][0] for i in range(len(X_valid))], [X_valid[i][1] for i in range(len(X_valid))]

    train_dataset = NewDataset(image_train, text_train, y_train, token)
    train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
    valid_dataset = NewDataset(image_valid, text_valid, y_valid, token)
    valid_dataloader = DataLoader(valid_dataset, batch_size=16, shuffle=True)

    # 模型训练
    train_model(model, epoch_num, optimizer, train_dataloader, valid_dataloader, len(X_train), len(X_valid))

    # 预测集进行预测
    emo_list = ['neutral', 'negative', 'positive']
    test_df = pd.read_csv('./test_without_label.txt')
    guid_list = test_df['guid'].tolist()
    tag_pre = []
    for idx in guid_list:
        img = Image.open('./data/' + str(idx) + '.jpg')
        img = img.resize((224, 224), Image.Resampling.LANCZOS)
        image = np.asarray(img, dtype='float32')
        image = image.transpose(2,0,1)
        with open('./data/' + str(idx) + '.txt', encoding='gb18030') as fp:
            description = fp.read()
        input_id, mask = word_embed([description], token)
        image = image.reshape(1, image.shape[0], image.shape[1], image.shape[2])
        y_pred = model(input_id.to(device), mask.to(device), torch.Tensor(image).to(device))
        tag_pre.append(emo_list[y_pred[0].argmax(dim=-1).item()])
    
    result_df = pd.DataFrame({'guid':guid_list, 'tag':tag_pre})
    result_df.to_csv('./bert_alexnet.txt',sep=',',index=False)

# %%
if __name__ == '__main__':
    main()
# Out:
# /root/miniconda3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /root/miniconda3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train Epoch: 1, Train Loss: 3.5289, Train Accuracy: 0.4662, Valid Accuracy: 0.5563
# Train Epoch: 2, Train Loss: 0.7428, Train Accuracy: 0.6353, Valid Accuracy: 0.6138
# Train Epoch: 3, Train Loss: 2.2844, Train Accuracy: 0.7269, Valid Accuracy: 0.6600
# Train Epoch: 4, Train Loss: 0.2986, Train Accuracy: 0.8247, Valid Accuracy: 0.6837
# Train Epoch: 5, Train Loss: 0.6866, Train Accuracy: 0.8938, Valid Accuracy: 0.6813
# Train Epoch: 6, Train Loss: 0.3228, Train Accuracy: 0.9331, Valid Accuracy: 0.6800
# Train Epoch: 7, Train Loss: 0.1158, Train Accuracy: 0.9550, Valid Accuracy: 0.6963
# Train Epoch: 8, Train Loss: 0.0542, Train Accuracy: 0.9600, Valid Accuracy: 0.6987
# Train Epoch: 9, Train Loss: 0.0112, Train Accuracy: 0.9716, Valid Accuracy: 0.7000
# Train Epoch: 10, Train Loss: 0.0003, Train Accuracy: 0.9747, Valid Accuracy: 0.7000
